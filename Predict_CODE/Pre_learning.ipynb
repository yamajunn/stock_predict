# %%
import os
import pandas as pd
import numpy as np
import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping# データディレクトリのパス
data_dir = '../stocks/stocks/'

# CSVファイルのパスを取得
csv_files = glob.glob(os.path.join(data_dir, '*.csv'))
print(csv_files)
# データフレームのリスト
data_list = []

# 各CSVファイルを読み込み、'Date'と'Open'列を抽出
for file in csv_files:
    df = pd.read_csv(file)
    # 'Date'と'Open'列のみを使用
    df = df[['Date', 'Open']]
    # ファイル名を識別子として追加（必要に応じて）
    ticker = os.path.basename(file).split('.')[0]
    df['Ticker'] = ticker
    data_list.append(df)

# すべてのデータを結合
all_data = pd.concat(data_list, ignore_index=True)

# 日付でソート
all_data['Date'] = pd.to_datetime(all_data['Date'])
all_data.sort_values('Date', inplace=True)

# 重複した日付を持つ場合、平均を取る（または他の方法で処理）
all_data = all_data.groupby('Date')['Open'].mean().reset_index()# 特徴量と目的変数の作成
# 過去30日間の'Open'値を使用して、次の日の'Open'値を予測

def create_sequences(data, window_size):
    X = []
    y = []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    return np.array(X), np.array(y)

window_size = 30  # 過去30日間
data_values = all_data['Open'].values

X, y = create_sequences(data_values, window_size)# 訓練用とテスト用に分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# スケーラーの定義
scaler_X = StandardScaler()
scaler_y = StandardScaler()

# Xのスケーリング
X_train = scaler_X.fit_transform(X_train)
X_test = scaler_X.transform(X_test)

# yのスケーリング
y_train = scaler_y.fit_transform(y_train.reshape(-1, 1))
y_test = scaler_y.transform(y_test.reshape(-1, 1))

# LSTMの入力に合わせて次元を変更
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)# 事前学習用のLSTMモデルを構築
pretrain_model = Sequential()
pretrain_model.add(LSTM(64, input_shape=(window_size, 1), return_sequences=True))
pretrain_model.add(LSTM(32))
pretrain_model.add(Dense(1))

pretrain_model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# 早期停止の設定
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# モデルの事前学習
pretrain_history = pretrain_model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    # callbacks=[early_stopping]
)# 事前学習済みモデルの保存
pretrain_model.save('pretrained_lstm_model.h5')
# Out:
# ['../stocks/stocks\\A.csv', '../stocks/stocks\\AA.csv', '../stocks/stocks\\AACG.csv', '../stocks/stocks\\AAL.csv', '../stocks/stocks\\AAMC.csv', '../stocks/stocks\\AAME.csv', '../stocks/stocks\\AAN.csv', '../stocks/stocks\\AAOI.csv', '../stocks/stocks\\AAON.csv', '../stocks/stocks\\AAP.csv', '../stocks/stocks\\AAPL.csv', '../stocks/stocks\\AAT.csv', '../stocks/stocks\\AAU.csv', '../stocks/stocks\\AAWW.csv', '../stocks/stocks\\AAXN.csv', '../stocks/stocks\\AB.csv', '../stocks/stocks\\ABB.csv', '../stocks/stocks\\ABBV.csv', '../stocks/stocks\\ABC.csv', '../stocks/stocks\\ABCB.csv', '../stocks/stocks\\ABEO.csv', '../stocks/stocks\\ABEV.csv', '../stocks/stocks\\ABG.csv', '../stocks/stocks\\ABIO.csv', '../stocks/stocks\\ABM.csv', '../stocks/stocks\\ABMD.csv', '../stocks/stocks\\ABR.csv', '../stocks/stocks\\ABT.csv', '../stocks/stocks\\ABTX.csv', '../stocks/stocks\\ABUS.csv', '../stocks/stocks\\AC.csv', '../stocks/stocks\\ACA.csv', '../stocks/stocks\\ACAD.csv', '../stocks/stocks\\ACAM.csv', '../stocks/stocks\\ACAMU.csv', '../stocks/stocks\\ACB.csv', '../stocks/stocks\\ACBI.csv', '../stocks/stocks\\ACC.csv', '../stocks/stocks\\ACCO.csv', '../stocks/stocks\\ACEL.csv', '../stocks/stocks\\ACER.csv', '../stocks/stocks\\ACGL.csv', '../stocks/stocks\\ACGLO.csv', '../stocks/stocks\\ACGLP.csv', '../stocks/stocks\\ACH.csv', '../stocks/stocks\\ACHC.csv', '../stocks/stocks\\ACHV.csv', '../stocks/stocks\\ACIA.csv', '../stocks/stocks\\ACIU.csv', '../stocks/stocks\\ACIW.csv', '../stocks/stocks\\ACLS.csv', '../stocks/stocks\\ACM.csv', '../stocks/stocks\\ACMR.csv', '../stocks/stocks\\ACN.csv', '../stocks/stocks\\ACNB.csv', '../stocks/stocks\\ACOR.csv', '../stocks/stocks\\ACP.csv', '../stocks/stocks\\ACRE.csv', '../stocks/stocks\\ACRS.csv', '../stocks/stocks\\ACRX.csv', '../stocks/stocks\\ACST.csv', '../stocks/stocks\\ACTG.csv', '../stocks/stocks\\ACTT.csv', '../stocks/stocks\\ACTTU.csv', '../stocks/stocks\\ACU.csv', '../stocks/stocks\\ACV.csv', '../stocks/stocks\\ACY.csv', '../stocks/stocks\\ADAP.csv', '../stocks/stocks\\ADBE.csv', '../stocks/stocks\\ADC.csv', '../stocks/stocks\\ADES.csv', '../stocks/stocks\\ADI.csv', '../stocks/stocks\\ADIL.csv', '../stocks/stocks\\ADM.csv', '../stocks/stocks\\ADMA.csv', '../stocks/stocks\\ADMP.csv', '../stocks/stocks\\ADMS.csv', '../stocks/stocks\\ADNT.csv', '../stocks/stocks\\ADP.csv', '../stocks/stocks\\ADPT.csv', '../stocks/stocks\\ADRO.csv', '../stocks/stocks\\ADS.csv', '../stocks/stocks\\ADSK.csv', '../stocks/stocks\\ADSW.csv', '../stocks/stocks\\ADT.csv', '../stocks/stocks\\ADTN.csv', '../stocks/stocks\\ADUS.csv', '../stocks/stocks\\ADVM.csv', '../stocks/stocks\\ADX.csv', '../stocks/stocks\\ADXN.csv', '../stocks/stocks\\ADXS.csv', '../stocks/stocks\\AE.csv', '../stocks/stocks\\AEB.csv', '../stocks/stocks\\AEE.csv', '../stocks/stocks\\AEF.csv', '../stocks/stocks\\AEFC.csv', '../stocks/stocks\\AEG.csv', '../stocks/stocks\\AEGN.csv', '../stocks/stocks\\AEHR.csv', '../stocks/stocks\\AEIS.csv', '../stocks/stocks\\AEL.csv', '../stocks/stocks\\AEM.csv', '../stocks/stocks\\AEMD.csv', '../stocks/stocks\\AEO.csv', '../stocks/stocks\\AEP.csv', '../stocks/stocks\\AER.csv', '../stocks/stocks\\AERI.csv', '../stocks/stocks\\AES.csv', '../stocks/stocks\\AESE.csv', '../stocks/stocks\\AEY.csv', '../stocks/stocks\\AEYE.csv', '../stocks/stocks\\AEZS.csv', '../stocks/stocks\\AFB.csv', '../stocks/stocks\\AFC.csv', '../stocks/stocks\\AFG.csv', '../stocks/stocks\\AFGC.csv', '../stocks/stocks\\AFGH.csv', '../stocks/stocks\\AFH.csv', '../stocks/stocks\\AFI.csv', '../stocks/stocks\\AFIN.csv', '../stocks/stocks\\AFINP.csv', '../stocks/stocks\\AFL.csv', '../stocks/stocks\\AFMD.csv', '../stocks/stocks\\AFT.csv', '../stocks/stocks\\AFYA.csv', '../stocks/stocks\\AG.csv', '../stocks/stocks\\AGBA.csv', '../stocks/stocks\\AGBAU.csv', '../stocks/stocks\\AGCO.csv', '../stocks/stocks\\AGD.csv', '../stocks/stocks\\AGE.csv', '../stocks/stocks\\AGEN.csv', '../stocks/stocks\\AGFS.csv', '../stocks/stocks\\AGI.csv', '../stocks/stocks\\AGIO.csv', '../s ...
# Epoch 1/100
# 294/294 [==============================] - 6s 12ms/step - loss: nan - val_loss: nan
# Epoch 2/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 3/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 4/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 5/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 6/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 7/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 8/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 9/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 10/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 11/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 12/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 13/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 14/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 15/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 16/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 17/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 18/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 19/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 20/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 21/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 22/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 23/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 24/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 25/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 26/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 27/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 28/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 29/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 30/100
# 294/294 [==============================] - 3s 11ms/step - loss: nan - val_loss: nan
# Epoch 31/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 32/100
# 294/294 [==============================] - 3s 11ms/step - loss: nan - val_loss: nan
# Epoch 33/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 34/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 35/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 36/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 37/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 38/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 39/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 40/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 41/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 42/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 43/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 44/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 45/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 46/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 47/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 48/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 49/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 50/100
# 294/294 [==============================] - 3s 11ms/step - loss: nan - val_loss: nan
# Epoch 51/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 52/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 53/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 54/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 55/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 56/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 57/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 58/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 59/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 60/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 61/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 62/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 63/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 64/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 65/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 66/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 67/100
# 294/294 [==============================] - 3s 11ms/step - loss: nan - val_loss: nan
# Epoch 68/100
# 294/294 [==============================] - 3s 11ms/step - loss: nan - val_loss: nan
# Epoch 69/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 70/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 71/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 72/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 73/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 74/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 75/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 76/100
# 294/294 [==============================] - 3s 11ms/step - loss: nan - val_loss: nan
# Epoch 77/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 78/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 79/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 80/100
# 294/294 [==============================] - 3s 11ms/step - loss: nan - val_loss: nan
# Epoch 81/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 82/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 83/100
# 294/294 [==============================] - 3s 11ms/step - loss: nan - val_loss: nan
# Epoch 84/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 85/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 86/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 87/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 88/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 89/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 90/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 91/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 92/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 93/100
# 294/294 [==============================] - 3s 11ms/step - loss: nan - val_loss: nan
# Epoch 94/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 95/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 96/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 97/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 98/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 99/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
# Epoch 100/100
# 294/294 [==============================] - 3s 10ms/step - loss: nan - val_loss: nan
